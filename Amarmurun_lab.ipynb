# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarmurun0212/Engineering/blob/main/Amarmurun_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("data_amur.csv")

df.head()
# Out:
#               Огноо  ЭУ-Зарцуулалтын хэмжээ, мян.м3  ЭУ-pH (замер)  \
# 0  2023.01.02 00:00                           173.1           7.54
# 1  2023.01.03 00:00                           171.8           7.71
# 2  2023.01.04 00:00                           191.6           7.60
# 3  2023.01.05 00:00                           186.6           7.58
# 4  2023.01.06 00:00                             NaN           7.68
#
#    ЭУ-Температур, 0С  ЭУ-ИАП, mv  ЭУ-Хатуулаг, мг-экв/л  ЭУ-Кальци, мг/л  \
# 0                2.2       169.5                  27.84            501.8
# 1                2.4       168.3                    NaN              NaN
# 2                2.1       156.4                  28.34            499.8
# 3                2.6       158.8                    NaN              NaN
# 4                1.9       159.1                  27.94            499.8
#
#    ЭУ-Магни, мг/л  ЭУ-Ууссан хүчилтөрөгч, мг/л  ЭУ-Умбуур бодис, мг/л  \
# ...

# %%
def histogram_intersection(a, b):
    v = np.minimum(a, b).sum().round(decimals=1)
    return v

# %%
df1 = df.loc[:, df.columns != "Огноо"]
df1.corr(method=histogram_intersection)
print(df1.corr())
# Out:
#                                         ЭУ-Зарцуулалтын хэмжээ, мян.м3  \
# ЭУ-Зарцуулалтын хэмжээ, мян.м3                                1.000000
# ЭУ-pH (замер)                                                -0.166372
# ЭУ-Температур, 0С                                             0.637993
# ЭУ-ИАП, mv                                                   -0.003152
# ЭУ-Хатуулаг, мг-экв/л                                        -0.587048
# ЭУ-Кальци, мг/л                                              -0.544988
# ЭУ-Магни, мг/л                                               -0.453582
# ЭУ-Ууссан хүчилтөрөгч, мг/л                                   0.437589
# ЭУ-Умбуур бодис, мг/л                                        -0.363913
# ЭУ-Ууссан хатуу бодис TDS, мг/л                              -0.497705
# ЭУ-Цахилгаан дамжуулах чанар EC, mS/cm                       -0.432515
# ТУ-Зарцуулалтын хэмжээ, мян.м3                               -0.682674
# ...

# %%
import numpy as np
data=df1.to_numpy()
data
# Out:
# array([[173.1   ,   7.54  ,   2.2   , ...,  86.5299,  56.8841,  30.9837],
#        [171.8   ,   7.71  ,   2.4   , ...,  86.5749,  52.9602,  29.7631],
#        [191.6   ,   7.6   ,   2.1   , ...,  86.1619,  58.553 ,  30.7078],
#        ...,
#        [348.6   ,   7.24  ,  16.7   , ...,  89.0586,  49.091 ,  31.6186],
#        [331.7   ,   7.18  ,  16.7   , ...,  89.299 ,  50.3452,  30.7416],
#        [329.3   ,   7.22  ,  17.7   , ...,  88.6729,  48.7001,  29.1066]])

# %%
print(df1.corr(method=histogram_intersection))
# Out:
#                                         ЭУ-Зарцуулалтын хэмжээ, мян.м3  \
# ЭУ-Зарцуулалтын хэмжээ, мян.м3                                     1.0
# ЭУ-pH (замер)                                                    933.3
# ЭУ-Температур, 0С                                                599.5
# ЭУ-ИАП, mv                                                     15789.1
# ЭУ-Хатуулаг, мг-экв/л                                           1784.0
# ЭУ-Кальци, мг/л                                                17006.6
# ЭУ-Магни, мг/л                                                  1875.4
# ЭУ-Ууссан хүчилтөрөгч, мг/л                                      119.6
# ЭУ-Умбуур бодис, мг/л                                           1149.1
# ЭУ-Ууссан хатуу бодис TDS, мг/л                                26631.7
# ЭУ-Цахилгаан дамжуулах чанар EC, mS/cm                           286.2
# ТУ-Зарцуулалтын хэмжээ, мян.м3                                  4327.9
# ...

# %%
import seaborn as sns
# %matplotlib inline

# calculate the correlation matrix on the numeric columns
corr = df1.select_dtypes('number').corr()

# plot the heatmap
sns.heatmap(corr)
# Out:
# <Axes: >
