# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarmurun0212/Engineering/blob/main/firstpandaas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

import pandas as pd
import matplotlib.pyplot as plt
#Machine learning 1: Prepare the data
dataset_path="/content/Data0110.xlsx"
df=pd.read_excel(dataset_path)
headers=list(df)
X=df[['Rost']]
Y=df[['Ves']]
plt.scatter(X,Y,color="black")
a=2.833
b=0.4129
Y1=a+b*X
plt.plot(X,Y1,"green")
plt.title("Зависимость вес и рост")
plt.grid()
plt.xlabel("Рост")
plt.ylabel("Вес")
plt.show()
