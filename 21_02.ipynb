# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarmurun0212/Engineering/blob/main/21_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.plot((0,1,2,3,4,5,6),(0,10,5,2,4,8,9))
plt.title('Первый график')
plt.xlabel('абс Х')
plt.ylabel('абс Y')
plt.scatter(1,10,c='c')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,4*np.pi,100)
plt.figure()
plt.plot(x,np.sin(x),'r-')
plt.plot(x,np.cos(x),'b--')
plt.title(' sin(x) и cos(x)')
plt.show()
