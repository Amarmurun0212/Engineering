# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarmurun0212/Engineering/blob/main/AI%26MLles1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Эхний кодын хичээл

# %% [markdown]
# ## Colabtai ажиллах

# %% [markdown]
# ### Жишээ кодууд бичих

# %% [markdown]
# #### Математик үйлдлүүд

# %%
365/7
# Out:
# 52.142857142857146

# %% [markdown]
# Сайнуу эх дэлхий минь

# %%
print('Сайнуу эх дэлхий минь')
# Out:
# Сайнуу эх дэлхий минь

# %% [markdown]
# Сан дуудах

# %%
import seaborn

# %%
import pandas as pd

# %% [markdown]
# # Хувьсагчтай ажиллах

# %% [markdown]
# # Хувьсагч
#
#
# *   Хувьсагчийг тодорхойлох шаардлагагүй
# *   Өгөгдлийг хадгалах зориулалттай
# *   Утга оноох үед шууд үүснэ

# %% [markdown]
# # Хувьсагчийн нэр
# * Заавал үсгээр эхлэх ёстой эсвэл (_)
# * Тоогоор эхлэж болохгүй
# * Зөвхөн үсэг тоо болон (_)-с бүрдэнэ
# * Том жижиг үсгийг ялгаатай гэж үзнэ.

# %%
a='энэ бол утга'
a
# Out:
# 'энэ бол утга'

# %%
Amarmurun = 'энд утга бичнэ'
Amarmurun
# Out:
# 'энд утга бичнэ'

# %%
1a = 'AMka'
# Out:
#   File "/tmp/ipykernel_5011/1382743688.py", line 1
#     1a = 'AMka'
#     ^
# SyntaxError: invalid decimal literal

# %%
_var = 'Энд утга бичнэ'
_var
# Out:
# 'Энд утга бичнэ'

# %%
Amar = 12
amar = 5
print(Amar, amar+8)
# Out:
# 12 13

# %%
a = 4
a = 6
print(a)
# Out:
# 6

# %% [markdown]
# # Өгөгдлийн төрлүүд

# %% [markdown]
# ## Numeric төрөл

# %% [markdown]
# ## integer төрөл

# %%
a = 100
b = 25
c = 23486121345312315432123456
print(a,b,c,c*1256)
# Out:
# 100 25 23486121345312315432123456 29498568409712268182747060736

# %%
# өгөгдлийн төрөл харах
type(c)
# Out:
# int

# %% [markdown]
# ## float төрөл

# %%
a = 2.03
b = 1e9
c = 1e-4
d = -3.14
print(a,b,c,d)
print(type(a),type(b),type(c),type(d),sep='\n')
# Out:
# 2.03 1000000000.0 0.0001 -3.14
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# ## Complex number

# %%
# j нь язгуур доор -1
a = 3+ 1j
print(a,type(a))
# Out:
# (3+1j) <class 'complex'>

# %%
# nemeh heseg baga zereg uur hiigdene
a= a+5+2j
print(a)
# Out:
# (8+3j)

# %% [markdown]
# ## Build-in Functions

# %%
# тоон төрлүүд дээр ажилладаг функцүүдийг үзье.
abs(-100)
#absolut buyu modul awch baina
# Out:
# 100

# %%
int (3.12542)
# Out:
# 3

# %%
int (5.84)
# Out:
# 5

# %%
float (100)
# Out:
# 100.0

# %%
complex(200)
# Out:
# (200+0j)

# %%
hex(12)
#urd taliin 0x ni 16tiin toolliin systemiig ilerhiilj baigaa. Tootooi hamaagui
# Out:
# '0xc'

# %% [markdown]
# # Logic төрөл

# %%
a = True
b = False
print(a,b,type(a),type(b))
# Out:
# True False <class 'bool'> <class 'bool'>

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %% [markdown]
# # String төрөл

# %%
name = 'Amarmurun'
print(name, type(name))
# Out:
# Amarmurun <class 'str'>

# %%
name = 'ноён ' + name
print(name)
# Out:
# ноён ноён ноён Amarmurun

# %%
name = name - 'ноён'
print(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_16919/2679109418.py in <cell line: 0>()
# ----> 1 name = name - 'ноён'
#       2 print(name)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
name = name *3

# %%
print(name)
# Out:
# ноён ноён ноён Amarmurunноён ноён ноён Amarmurunноён ноён ноён Amarmurun

# %%
name.upper()
# Out:
# 'НОЁН НОЁН НОЁН AMARMURUNНОЁН НОЁН НОЁН AMARMURUNНОЁН НОЁН НОЁН AMARMURUN'

# %%
name.lower()
# Out:
# 'ноён ноён ноён amarmurunноён ноён ноён amarmurunноён ноён ноён amarmurun'

# %%
name2 = '         amka         '
print(name2)
# Out:
#          amka

# %%
name2.strip()
# Out:
# 'amka'

# %%
name2.lstrip()
# Out:
# 'amka         '

# %%
name2.rstrip()
# Out:
# '         amka'

# %%
email='amka#gmail.com'

# %%
email.replace('#','@')
# Out:
# 'amka@gmail.com'
